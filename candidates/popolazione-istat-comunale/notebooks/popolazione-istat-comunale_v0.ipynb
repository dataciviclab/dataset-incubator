# %% [markdown]
# # Popolazione ISTAT Comunale – Notebook v0
# Questo notebook contiene il setup iniziale per il candidate **popolazione-istat-comunale**.

# %%
# Setup METRICHE e variabili di esempio
METRICHE = ["popolazione"]
ANNO = 2024
DATASET_SLUG = "popolazione-istat-comunale"
print(f"Metriche: {METRICHE}, Anno: {ANNO}, Dataset: {DATASET_SLUG}")

# %%
# Esempio di caricamento dati (simulato)
import pandas as pd
# In un contesto reale, si userebbe DuckDB o GCS per leggere il parquet
# df = duckdb.read_parquet(f"gs://dataciviclab-data/popolazione_istat_comunale/{ANNO}.parquet")
df = pd.DataFrame({
    "comune_id": [1, 2, 3],
    "anno": [ANNO, ANNO, ANNO],
    "popolazione": [12000, 8500, 4300]
})
df.head()
